# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
data = pd.read_excel('D:/Google_Drive/Vasant_Kunj_DWQ/Data/Chem_Project_Readings_06_05_2018.xlsx')

# Extract the data 
lat = data['Ycoord'].values
lon = data['Xcoord'].values
TH_Tap =  data['Mean Total Hardness-Tap Water'].values
TH_RO =  data['Mean Total Hardness-RO Water'].values
CH_Tap = data['Mean Calcium Hardness -Tap Water'].values
CH_RO = data['Mean Calcium Hardness-RO Water'].values
MG_Tap = data['Mean Mg Hardness-Tap Water'].values
MG_RO = data['Mean Mg Hardness-RO Water'].values
TDS_Tap = data['Mean TDS-Tap'].values
TDS_RO = data['Mean TDS-RO'].values
CL_Tap = data['Mean Chloride-Tap'].values
CL_RO = data['Mean Chloride-RO'].values

# %%
fig = plt.figure(figsize=(10, 10))
m = Basemap(projection='lcc', resolution=None,
            width=8E6, height=8E6, 
            lat_0=28, lon_0=70,)
m.etopo(scale=1.5, alpha=0.8)

m.scatter(lon, lat, latlon=True,
          c=np.log10(TH_Tap), s=area,
          cmap='Reds', alpha=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-1b371a6389b3> in <module>
#       3             width=8E6, height=8E6,
#       4             lat_0=28, lon_0=70,)
# ----> 5 m.etopo(scale=1.5, alpha=0.8)
#       6
#       7 m.scatter(lon, lat, latlon=True,
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in etopo(self, ax, scale, **kwargs)
#    4006             return self.warpimage(image='etopo',ax=ax,scale=scale,**kwargs)
#    4007         else:
# -> 4008             return self.warpimage(image='etopo',scale=scale,**kwargs)
#    4009
#    4010     def warpimage(self,image="bluemarble",scale=None,**kwargs):
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
# ...

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy.ma as ma
from numpy.random import uniform, seed
# make up some randomly distributed data


zi = griddata((lon, lat), TH_Tap, (lon[None,:], lat[:,None]))
CS = plt.contour(lon, lat,zi,15,linewidths=0.5,colors='k')
CS = plt.contourf(lon, lat,zi,15,cmap=plt.cm.jet)
plt.colorbar() # draw colorbar
# plot data points.
plt.scatter(lon,lat,marker='o',c='b',s=5)
plt.title('')
plt.show()
